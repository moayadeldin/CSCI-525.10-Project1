# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (1.26.0)
# Requirement already satisfied: scipy in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (1.11.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 1)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 1)) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data_preprocessed.csv")

# %%
filtered_df = df[df["price"] >= 1000]

print(len(filtered_df["price"]))
print(max(filtered_df["price"]))

plt.figure(figsize=(10, 6))
plt.hist(filtered_df["price"], bins=50, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Price Distribution (Ignoring Values Below 1000)")
plt.show()
# Out:
# 701
# 99000

# %%
filtered_df = df[df["price"] <= 1000]

print(len(filtered_df["price"]))
print(max(filtered_df["price"]))

plt.figure(figsize=(10, 6))
plt.hist(filtered_df["price"], bins=50, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Price Distribution (Ignoring Values Above 1000)")
plt.xlim(0, 1000)
plt.show()
# Out:
# 42305
# 1000
